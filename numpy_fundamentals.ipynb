# %%
#importing numpy package
import numpy as np

# %%
#Creating numpy array by using array();
value=45;
numpy_value=np.array(value)

# %%
numpy_value
# Out:
# array(45)

# %%
type(numpy_value)
# Out:
# numpy.ndarray

# %%
numpy_value.ndim
# Out:
# 0

# %%
#Creating the numpy array with group of values
numpy_values1=np.array([10,20,30,40,50,60])
numpy_values1
# Out:
# array([10, 20, 30, 40, 50, 60])

# %%
numpy_values.ndim
# Out:
# 1

# %%
#Creating numpy array with  nested list or Creating a matrix
numpy_values2=np.array([[10,20,30,40],[50,60,70,80]]); # It is called as matrix
numpy_values2
# Out:
# array([[10, 20, 30, 40],
#        [50, 60, 70, 80]])

# %%
numpy_values2.ndim
# Out:
# 2

# %%
#Creating numpy array with multiple nested list or Creating a matrix
numpy_values3=np.array([[10,20,30],[40,50,60],[70,80,90]]); # It is called as matrix
numpy_values3
# Out:
# array([[10, 20, 30],
#        [40, 50, 60],
#        [70, 80, 90]])

# %%
numpy_values3.ndim
# Out:
# 2

# %% [markdown]
# Indexing

# %%
#We can access numpy array values by using indexing
numpy_values1
# Out:
# array([10, 20, 30, 40, 50, 60])

# %%
numpy_values1[0] #Indexing always starts zero
# Out:
# np.int64(10)

# %%
numpy_values1[1]
# Out:
# np.int64(20)

# %%
numpy_values1[4]
# Out:
# np.int64(50)

# %%
numpy_values2
# Out:
# array([[10, 20, 30, 40],
#        [50, 60, 70, 80]])

# %%
numpy_values2[0][0] # We can access matrix values by using row and column indexing
# Out:
# np.int64(10)

# %%
numpy_values2[0][3]
# Out:
# np.int64(40)

# %%
numpy_values2[1][2]
# Out:
# np.int64(70)

# %% [markdown]
# Slicing

# %%
numpy_values1
# Out:
# array([10, 20, 30, 40, 50, 60])

# %%
numpy_values1[2:3] # We can access numpy values by using slicing also
# Out:
# array([30])

# %%
numpy_values1[:]  # Accessing entire numpy array
# Out:
# array([10, 20, 30, 40, 50, 60])

# %%
numpy_values1[::-1] # Reverse the numpy array
# Out:
# array([60, 50, 40, 30, 20, 10])
